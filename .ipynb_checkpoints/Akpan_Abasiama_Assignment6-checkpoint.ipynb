# %%
import matplotlib.pyplot as pl

def pairs(data):
    """Generates and shows a pairwise scatterplot of the dataset features.

    A figure with nxn scatterplots is generated, where n is the number of features. The features are
    defined as the all columns excluding the final column, which is defined as the class.

    Args:
      data (array): A dataset.

    """
    i = 1

    # Divide columns into features and class.
    features = list(data.columns)
    classes = features[-1] # create class column
    del features[-1] # delete class column from feature vector

    # Generate an nxn subplot figure, where n is the number of features.
    figure = pl.figure(figsize=(5*(len(data.columns)-1), 4*(len(data.columns)-1)))
    for col1 in data[features]:
        for col2 in data[features]:
            ax = pl.subplot(len(data.columns)-1, len(data.columns)-1, i)
            if col1 == col2:
                ax.text(2.5, 4.5, col1, style='normal', fontsize=20)
                ax.axis([0, 10, 0, 10])
                pl.xticks([]), pl.yticks([])
            else:
                for name in data[classes]:
                    cond = data[classes] == name
                    ax.plot(data[col2][cond], data[col1][cond], linestyle='none', marker='o', label=name)
                #t = plt.title(name)
            i += 1

    pl.show()

# %%
import pandas as pd
fileURL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris=pd.read_csv(fileURL, names = ['Sepal Length', 'Sepal Width','Petal Length','Petal Width','Species'], header=None)
iris=iris.dropna()

# %% [markdown]
# ### A scatterplot matrix of scatterplots, with one scatterplot for each pairwise combination of features ###

# %%
pairs(iris)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import datasets, linear_model
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import mean_squared_error, r2_score


def split_iris_datasets(predictor, target):
    
    #Split arrays or matrices into random train and test subsets
    X = iris[predictor]
    y = iris[target]
    iris_X_train, iris_X_test, iris_y_train, iris_y_test = train_test_split(X, y, test_size = 0.6, random_state=42)
    return iris_X_train, iris_X_test, iris_y_train, iris_y_test

# %%
def calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test):
    # Train the model using the training sets
    regr.fit(iris_X_train,iris_y_train)
    # The coefficients
    print('Coefficients: \n', regr.coef_)
    # The mean squared error
    print('Mean squared error: %.2f'
          % mean_squared_error(iris_y_test, regr.predict(iris_X_test)))
    # The coefficient of determination: 1 is perfect prediction
    print('Coefficient of determination: %.2f' % r2_score(iris_y_test, regr.predict(iris_X_test)))
    
    print ('Variance Score: %.2f' % regr.score(iris_X_test, iris_y_test))
   
    # Plot outputs
    plt.scatter(iris_X_test, iris_y_test,  color='black')
    plt.plot(iris_X_test, regr.predict(iris_X_test), color='blue', linewidth=3)
    pl.xlabel(predictor[0])
    pl.ylabel(target)
    plt.title(target + " vs " + predictor[0], fontsize=15, fontweight='bold')

    plt.show()

# %% [markdown]
# ### A plot of the linear regression models generated on each pairwise combination of features, with corresponding model statistics. ###

# %% [markdown]
# ### Petal Width vs Petal Length ###

# %%
#Split arrays or matrices into random train and test subsets
predictor=['Petal Length']
target='Petal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
# Calculate and plot linear regression models
Models
# Out:
# Coefficients:
#  [0.41460753]
# Mean squared error: 0.04
# Coefficient of determination: 0.94
# Variance Score: 0.94

# %% [markdown]
# ###  Sepal Length vs Petal Length ###

# %%
predictor=['Petal Length']
target='Sepal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.44349103]
# Mean squared error: 0.16
# Coefficient of determination: 0.75
# Variance Score: 0.75

# %% [markdown]
# ###  Sepal Width vs Petal Length ###

# %%
predictor=['Petal Length']
target='Sepal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [-0.05726851]
# Mean squared error: 0.19
# Coefficient of determination: 0.11
# Variance Score: 0.11

# %% [markdown]
# ###  Petal Length vs Petal Width ###

# %%
predictor=['Petal Width']
target='Petal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [2.19008616]
# Mean squared error: 0.21
# Coefficient of determination: 0.93
# Variance Score: 0.93

# %% [markdown]
# ###   Sepal Width vs Petal Width ###

# %%
predictor=['Petal Width']
target='Sepal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [-0.08889108]
# Mean squared error: 0.21
# Coefficient of determination: 0.04
# Variance Score: 0.04

# %% [markdown]
# ### Sepal Length vs Petal Width ###

# %%
predictor=['Petal Width']
target='Sepal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.93659466]
# Mean squared error: 0.20
# Coefficient of determination: 0.69
# Variance Score: 0.69

# %% [markdown]
# ### Sepal Width vs Sepal Length ###

# %%
predictor=['Sepal Length']
target='Sepal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.01053169]
# Mean squared error: 0.24
# Coefficient of determination: -0.09
# Variance Score: -0.09

# %% [markdown]
# ### Petal Width vs Sepal Length ###

# %%
predictor=['Sepal Length']
target='Petal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.6770732]
# Mean squared error: 0.20
# Coefficient of determination: 0.66
# Variance Score: 0.66

# %% [markdown]
# ### Petal Length vs Sepal Length ###

# %%
predictor=['Sepal Length']
target='Petal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [1.69352967]
# Mean squared error: 0.83
# Coefficient of determination: 0.74
# Variance Score: 0.74

# %% [markdown]
# ### Sepal Length vs Sepal Width ###

# %%
predictor=['Sepal Width']
target='Sepal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.05893476]
# Mean squared error: 0.67
# Coefficient of determination: -0.05
# Variance Score: -0.05

# %% [markdown]
# ### Petal Length vs Sepal Width ###

# %%
predictor=['Sepal Width']
target='Petal Length'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [-1.223763]
# Mean squared error: 2.63
# Coefficient of determination: 0.17
# Variance Score: 0.17

# %% [markdown]
# ### Petal Width vs Sepal Width ###

# %%
predictor=['Sepal Width']
target='Petal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [-0.3595966]
# Mean squared error: 0.53
# Coefficient of determination: 0.10
# Variance Score: 0.10

# %%
def show_pairwise_scatter_plot_w_regression(data):
    """Generates and shows a pairwise scatterplot of the dataset features.

    A figure with nxn scatterplots is generated, where n is the number of features. The features are
    defined as the all columns excluding the final column, which is defined as the class.

    Args:
      data (array): A dataset.

    """
    i = 1

    # Divide columns into features and class.
    features = list(data.columns)
    classes = features[-1] # create class column
    del features[-1] # delete class column from feature vector

    # Generate an nxn subplot figure, where n is the number of features.
    figure = pl.figure(figsize=(5*(len(data.columns)-1), 4*(len(data.columns)-1)))
    for col1 in data[features]:
        for col2 in data[features]:
            ax = pl.subplot(len(data.columns)-1, len(data.columns)-1, i)
            if col1 == col2:
                ax.text(2.5, 4.5, col1, style='normal', fontsize=20)
                ax.axis([0, 10, 0, 10])
                pl.xticks([]), pl.yticks([])
            else:
                for name in data[classes]:
                    cond = data[classes] == name
                ax.plot(data[col2][cond], data[col1][cond], linestyle='none', marker='o', label=name)
                #t = plt.title(name)
                
                #Split arrays or matrices into random train and test subsets
                iris_X_train, iris_X_test, iris_y_train, iris_y_test = train_test_split(data[col2], data[col1], test_size=0.6, random_state=42)
                
                #Gives a new shape to an array without changing its data.
                iris_X_train = iris_X_train.values.reshape(-1, 1)
                iris_y_train = iris_y_train.values.reshape(-1, 1)
                iris_X_test = iris_X_test.values.reshape(-1, 1)
                iris_y_test = iris_y_test.values.reshape(-1, 1)
                # Create linear regression object
                regr = linear_model.LinearRegression()
                # Train the model using the training sets
                regr.fit(iris_X_train, iris_y_train)
                ax.plot(iris_X_test, regr.predict(iris_X_test), color='blue', linewidth=3)
                    
            i += 1

    pl.show()

# %%
show_pairwise_scatter_plot_w_regression(iris)

# %% [markdown]
# #### Fig 1: Pairwise Scatter Plot with linear regression ####

# %% [markdown]
# ### A plot of the best overall linear regression model you were able to generate using any combination of features (including the use of multiple features used in combination to predict a single feature), with corresponding model statistics. ###

# %%
predictor=['Petal Length']
target='Petal Width'
iris_X_train,iris_X_test,iris_y_train,iris_y_test=split_iris_datasets(predictor,target)

# %%
regr = linear_model.LinearRegression()

# %%
calculate_and_plot_iris_linear_regression(regr, iris_X_train, iris_X_test, iris_y_train, iris_y_test)
# Out:
# Coefficients:
#  [0.41460753]
# Mean squared error: 0.04
# Coefficient of determination: 0.94
# Variance Score: 0.94

# %% [markdown]
# ## Part 1 ##

# %% [markdown]
# As seen from the individual linear models and Fig 1, it is clear that Petal Length and Width pairs are the most predictive of one another because the linear regression resulting plot shows that one can predict the outcome of the other. We can see this in the variance score of petal length v. width (0.94), which means that 94% of the variance is captured

# %% [markdown]
# ## Part 2 ##

# %% [markdown]
# Lets say we remove either Petal Length or Petal Width. The classification performance will be affected slightly but should not have a dramatic effect on performance because you could predict one or the other without having both features present. However, removing a feature like Sepal Length could have dramatic effects on the classification performance as valauble information can be omitted when classifying other features against it. We can see this in the variance score of petal length v. sepal width is only 0.17, which means 83% of the variance is unexplained.
