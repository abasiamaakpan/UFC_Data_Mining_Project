# %% [markdown]
# # Reading the Data

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn import datasets, linear_model
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("data.csv")
df.head(5)
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                    0.0  ...              2.0                  0.0
# 1                    0.0  ...              0.0                  2.0
# 2                    0.0  ...              3.0                  6.0
# 3                    0.0  ...              1.0                  0.0
# 4                    0.0  ...              2.0                  0.0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                           0.0     8.0  Orthodox        162.56       162.56
# 1                           0.0     5.0  Southpaw        165.10       167.64
# 2                           1.0    14.0  Orthodox        180.34       193.04
# 3                           0.0     6.0  Orthodox        162.56       172.72
# 4                           0.0     3.0  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %%
# Dropping unnecessary rows and filling in values

# %%
# Show number of matches in dataset before removing matches with missing stance information
print('Number of matches prior to filtering: ' + str(len(df)))

# Remove matches with missing stance information
filter1 = df[df['B_Stance'].notnull()]
filter2 = filter1[filter1['R_Stance'].notnull()]
filter3 = filter2[filter2['Referee'].notnull()]
df = filter3
print('Number of matchs after filtering: ' + str(len(filter3)))
# Out:
# Number of matches prior to filtering: 5144
# Number of matchs after filtering: 4865

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['B_avg_BODY_att', 'B_avg_BODY_landed', 'B_avg_CLINCH_att',
#        'B_avg_CLINCH_landed', 'B_avg_DISTANCE_att', 'B_avg_DISTANCE_landed',
#        'B_avg_GROUND_att', 'B_avg_GROUND_landed', 'B_avg_HEAD_att',
#        'B_avg_HEAD_landed',
#        ...
#        'R_avg_opp_SUB_ATT', 'R_avg_opp_TD_att', 'R_avg_opp_TD_landed',
#        'R_avg_opp_TD_pct', 'R_avg_opp_TOTAL_STR_att',
#        'R_avg_opp_TOTAL_STR_landed', 'R_total_time_fought(seconds)',
#        'R_Reach_cms', 'B_age', 'R_age'],
#       dtype='object', length=104)

# %%
people = df[df['R_age'].isnull()].head(5)
people
# Out:
#          R_fighter       B_fighter           Referee        date  \
# 4171    Per Eklund    Samy Schiavo      Leon Roberts  2008-10-18
# 4376  Jess Liaudin  Anthony Torres    Mario Yamasaki  2007-09-08
# 4438  Jess Liaudin    Dennis Siver  Steve Mazzagatti  2007-04-21
# 4767  Keith Rockel   Chris Liguori     John McCarthy  2003-11-21
# 4908   Ben Earwood     Chris Lytle    Mario Yamasaki  2000-11-17
#
#                                  location Winner  title_bout  weight_class  \
# 4171  Birmingham, England, United Kingdom    Red       False   Lightweight
# 4376      London, England, United Kingdom    Red       False  Welterweight
# 4438  Manchester, England, United Kingdom    Red       False  Welterweight
# 4767         Uncasville, Connecticut, USA    Red       False  Middleweight
# 4908       Atlantic City, New Jersey, USA    Red       False  Welterweight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 4171             3                    1.0  ...              0.0
# 4376             3                    0.0  ...              0.0
# 4438             3                    0.0  ...              0.0
# 4767             3                    0.0  ...              0.0
# 4908             2                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4171                  0.0                           0.0     0.0  Orthodox
# 4376                  1.0                           0.0     1.0  Orthodox
# 4438                  0.0                           0.0     0.0  Orthodox
# 4767                  0.0                           0.0     0.0  Orthodox
# 4908                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4171        177.80       182.88         155.0   32.0    NaN
# 4376        175.26       182.88         170.0   29.0    NaN
# 4438        175.26       182.88         170.0   28.0    NaN
# 4767        182.88          NaN         185.0    NaN    NaN
# 4908        172.72          NaN         170.0   26.0    NaN
#
# [5 rows x 145 columns]

# %%
df['R_age'].median()
# Out:
# 29.0

# %%
df = df.fillna(df.median())
df.loc[people.index.tolist()]
# Out:
#          R_fighter       B_fighter           Referee        date  \
# 4171    Per Eklund    Samy Schiavo      Leon Roberts  2008-10-18
# 4376  Jess Liaudin  Anthony Torres    Mario Yamasaki  2007-09-08
# 4438  Jess Liaudin    Dennis Siver  Steve Mazzagatti  2007-04-21
# 4767  Keith Rockel   Chris Liguori     John McCarthy  2003-11-21
# 4908   Ben Earwood     Chris Lytle    Mario Yamasaki  2000-11-17
#
#                                  location Winner  title_bout  weight_class  \
# 4171  Birmingham, England, United Kingdom    Red       False   Lightweight
# 4376      London, England, United Kingdom    Red       False  Welterweight
# 4438  Manchester, England, United Kingdom    Red       False  Welterweight
# 4767         Uncasville, Connecticut, USA    Red       False  Middleweight
# 4908       Atlantic City, New Jersey, USA    Red       False  Welterweight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 4171             3                    1.0  ...              0.0
# 4376             3                    0.0  ...              0.0
# 4438             3                    0.0  ...              0.0
# 4767             3                    0.0  ...              0.0
# 4908             2                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4171                  0.0                           0.0     0.0  Orthodox
# 4376                  1.0                           0.0     1.0  Orthodox
# 4438                  0.0                           0.0     0.0  Orthodox
# 4767                  0.0                           0.0     0.0  Orthodox
# 4908                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4171        177.80       182.88         155.0   32.0   29.0
# 4376        175.26       182.88         170.0   29.0   29.0
# 4438        175.26       182.88         170.0   28.0   29.0
# 4767        182.88       185.42         185.0   29.0   29.0
# 4908        172.72       185.42         170.0   26.0   29.0
#
# [5 rows x 145 columns]

# %% [markdown]
# # Adding the Gender column

# %%
view = df
#dropping duplicates
newView = view.drop_duplicates(subset = "B_fighter", keep = "first")

newView.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                    0.0  ...              2.0                  0.0
# 1                    0.0  ...              0.0                  2.0
# 2                    0.0  ...              3.0                  6.0
# 3                    0.0  ...              1.0                  0.0
# 4                    0.0  ...              2.0                  0.0
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                           0.0     8.0  Orthodox        162.56       162.56
# 1                           0.0     5.0  Southpaw        165.10       167.64
# 2                           1.0    14.0  Orthodox        180.34       193.04
# 3                           0.0     6.0  Orthodox        162.56       172.72
# 4                           0.0     3.0  Southpaw        187.96       190.50
#
#    R_Weight_lbs  B_age  R_age
# 0         135.0   31.0   32.0
# 1         125.0   32.0   31.0
# 2         155.0   36.0   35.0
# 3         135.0   26.0   29.0
# 4         264.0   32.0   26.0
#
# [5 rows x 145 columns]

# %%
filtered_df_female_new  = newView.loc[(newView['weight_class'] == "Women's Bantamweight") | (newView['weight_class'] == "Women's Featherweight") | (newView['weight_class'] == "Women's Featherweight") | (newView['weight_class'] == "Women's Flyweight") | (newView['weight_class'] == "Women's Strawweight")]

# %%
filtered_df_male_new  = newView.loc[(newView['weight_class'] == "Bantamweight") | (newView['weight_class'] == "Catch Weight") | (newView['weight_class'] == "Featherweight") | (newView['weight_class'] == "Flyweight") | (newView['weight_class'] == "Heavyweight") | (newView['weight_class'] == "Light Heavyweight") | (newView['weight_class'] == "Lightweight") | (newView['weight_class'] == "Middleweight") | (newView['weight_class'] == "Open Weight") | (newView['weight_class'] == "Welterweight") ]

# %%
#female 0, male 1
filtered_df_female_new["Gender"]=0
filtered_df_male_new["Gender"]=1
# Out:
# <ipython-input-13-78a0c7a92a77>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_female_new["Gender"]=0
# <ipython-input-13-78a0c7a92a77>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_male_new["Gender"]=1

# %%
frames_new=[filtered_df_male_new,filtered_df_female_new]

# %%
finalView=pd.concat(frames_new)

# %%
#Males = 1
#Females = 0
finalView
# Out:
#               R_fighter        B_fighter            Referee        date  \
# 0          Henry Cejudo    Marlon Moraes       Marc Goddard  2019-06-08
# 2         Tony Ferguson   Donald Cerrone    Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera         Petr Yan    Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa    Blagoy Ivanov    Dan Miragliotta  2019-06-08
# 6     Aljamain Sterling     Pedro Munhoz       Marc Goddard  2019-06-08
# ...                 ...              ...                ...         ...
# 2073        Miesha Tate      Sara McMann       Marc Goddard  2015-01-31
# 2266    Jessica Andrade  Larissa Pacheco  Fernando Yamasaki  2014-09-13
# 2352    Claudia Gadelha   Tina Lahdemaki      Liam Kerrigan  2014-07-16
# 2798       Amanda Nunes      Sheila Gaff          Herb Dean  2013-08-03
# 2830       Alexis Davis      Rosi Sexton          Herb Dean  2013-06-15
#
#                                 location Winner  title_bout  \
# 0                 Chicago, Illinois, USA    Red        True
# 2                 Chicago, Illinois, USA    Red       False
# 3                 Chicago, Illinois, USA   Blue       False
# 4                 Chicago, Illinois, USA   Blue       False
# 6                 Chicago, Illinois, USA    Red       False
# ...                                  ...    ...         ...
# 2073              Las Vegas, Nevada, USA    Red       False
# 2266  Brasilia, Distrito Federal, Brazil    Red       False
# 2352      Atlantic City, New Jersey, USA    Red       False
# 2798              Rio de Janeiro, Brazil    Red       False
# 2830          Winnipeg, Manitoba, Canada    Red       False
#
#               weight_class  no_of_rounds  B_current_lose_streak  ...  \
# 0             Bantamweight             5                    0.0  ...
# 2              Lightweight             3                    0.0  ...
# 3             Bantamweight             3                    0.0  ...
# 4              Heavyweight             3                    0.0  ...
# 6             Bantamweight             3                    0.0  ...
# ...                    ...           ...                    ...  ...
# 2073  Women's Bantamweight             3                    0.0  ...
# 2266  Women's Bantamweight             3                    0.0  ...
# 2352   Women's Strawweight             3                    0.0  ...
# 2798  Women's Bantamweight             3                    1.0  ...
# 2830  Women's Bantamweight             3                    0.0  ...
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 0                     0.0                           0.0     8.0  Orthodox
# 2                     6.0                           1.0    14.0  Orthodox
# 3                     0.0                           0.0     6.0  Orthodox
# 4                     0.0                           0.0     3.0  Southpaw
# 6                     3.0                           0.0     9.0  Orthodox
# ...                   ...                           ...     ...       ...
# 2073                  0.0                           0.0     2.0  Orthodox
# 2266                  0.0                           0.0     2.0  Orthodox
# 2352                  0.0                           0.0     0.0  Orthodox
# 2798                  0.0                           0.0     0.0  Orthodox
# 2830                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age  Gender
# 0           162.56       162.56         135.0   31.0   32.0       1
# 2           180.34       193.04         155.0   36.0   35.0       1
# 3           162.56       172.72         135.0   26.0   29.0       1
# 4           187.96       190.50         264.0   32.0   26.0       1
# 6           170.18       180.34         135.0   32.0   29.0       1
# ...            ...          ...           ...    ...    ...     ...
# 2073        167.64       165.10         135.0   34.0   28.0       0
# 2266        154.94       157.48         115.0   20.0   22.0       0
# 2352        162.56       160.02         115.0   26.0   25.0       0
# 2798        172.72       175.26         145.0   23.0   25.0       0
# 2830        167.64       172.72         125.0   35.0   28.0       0
#
# [1662 rows x 146 columns]

# %%
df.to_csv("finalView.csv")
