# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import numpy as np 
from sklearn.model_selection import train_test_split
library("corrplot") # Correlation visualizations

df = pd.read_csv("data.csv")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-8e73150d17ed> in <module>
#       4 import numpy as np
#       5 from sklearn.model_selection import train_test_split
# ----> 6 library("corrplot") # Correlation visualizations
#       7
#       8 df = pd.read_csv("data.csv")
#
# NameError: name 'library' is not defined

# %%
# Show number of matches in dataset before removing matches with missing stance information
print('Number of matches prior to filtering: ' + str(len(df)))

# Remove matches with missing stance information
filter1 = df[df['B_Stance'].notnull()]
filter2 = filter1[filter1['R_Stance'].notnull()]
filter3 = filter2[filter2['Referee'].notnull()]
df = filter3
print('Number of matchs after filtering: ' + str(len(filter3)))
# Out:
# Number of matches prior to filtering: 5144
# Number of matchs after filtering: 4865

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['B_avg_BODY_att', 'B_avg_BODY_landed', 'B_avg_CLINCH_att',
#        'B_avg_CLINCH_landed', 'B_avg_DISTANCE_att', 'B_avg_DISTANCE_landed',
#        'B_avg_GROUND_att', 'B_avg_GROUND_landed', 'B_avg_HEAD_att',
#        'B_avg_HEAD_landed',
#        ...
#        'R_avg_opp_SUB_ATT', 'R_avg_opp_TD_att', 'R_avg_opp_TD_landed',
#        'R_avg_opp_TD_pct', 'R_avg_opp_TOTAL_STR_att',
#        'R_avg_opp_TOTAL_STR_landed', 'R_total_time_fought(seconds)',
#        'R_Reach_cms', 'B_age', 'R_age'],
#       dtype='object', length=104)

# %%
people = df[df['R_age'].isnull()].head(5)
people
# Out:
#          R_fighter       B_fighter           Referee        date  \
# 4171    Per Eklund    Samy Schiavo      Leon Roberts  2008-10-18
# 4376  Jess Liaudin  Anthony Torres    Mario Yamasaki  2007-09-08
# 4438  Jess Liaudin    Dennis Siver  Steve Mazzagatti  2007-04-21
# 4767  Keith Rockel   Chris Liguori     John McCarthy  2003-11-21
# 4908   Ben Earwood     Chris Lytle    Mario Yamasaki  2000-11-17
#
#                                  location Winner  title_bout  weight_class  \
# 4171  Birmingham, England, United Kingdom    Red       False   Lightweight
# 4376      London, England, United Kingdom    Red       False  Welterweight
# 4438  Manchester, England, United Kingdom    Red       False  Welterweight
# 4767         Uncasville, Connecticut, USA    Red       False  Middleweight
# 4908       Atlantic City, New Jersey, USA    Red       False  Welterweight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 4171             3                    1.0  ...              0.0
# 4376             3                    0.0  ...              0.0
# 4438             3                    0.0  ...              0.0
# 4767             3                    0.0  ...              0.0
# 4908             2                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4171                  0.0                           0.0     0.0  Orthodox
# 4376                  1.0                           0.0     1.0  Orthodox
# 4438                  0.0                           0.0     0.0  Orthodox
# 4767                  0.0                           0.0     0.0  Orthodox
# 4908                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4171        177.80       182.88         155.0   32.0    NaN
# 4376        175.26       182.88         170.0   29.0    NaN
# 4438        175.26       182.88         170.0   28.0    NaN
# 4767        182.88          NaN         185.0    NaN    NaN
# 4908        172.72          NaN         170.0   26.0    NaN
#
# [5 rows x 145 columns]

# %%
df['R_age'].median()
# Out:
# 29.0

# %%
df = df.fillna(df.median())
df.loc[people.index.tolist()]
# Out:
#          R_fighter       B_fighter           Referee        date  \
# 4171    Per Eklund    Samy Schiavo      Leon Roberts  2008-10-18
# 4376  Jess Liaudin  Anthony Torres    Mario Yamasaki  2007-09-08
# 4438  Jess Liaudin    Dennis Siver  Steve Mazzagatti  2007-04-21
# 4767  Keith Rockel   Chris Liguori     John McCarthy  2003-11-21
# 4908   Ben Earwood     Chris Lytle    Mario Yamasaki  2000-11-17
#
#                                  location Winner  title_bout  weight_class  \
# 4171  Birmingham, England, United Kingdom    Red       False   Lightweight
# 4376      London, England, United Kingdom    Red       False  Welterweight
# 4438  Manchester, England, United Kingdom    Red       False  Welterweight
# 4767         Uncasville, Connecticut, USA    Red       False  Middleweight
# 4908       Atlantic City, New Jersey, USA    Red       False  Welterweight
#
#       no_of_rounds  B_current_lose_streak  ...  R_win_by_KO/TKO  \
# 4171             3                    1.0  ...              0.0
# 4376             3                    0.0  ...              0.0
# 4438             3                    0.0  ...              0.0
# 4767             3                    0.0  ...              0.0
# 4908             2                    0.0  ...              0.0
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 4171                  0.0                           0.0     0.0  Orthodox
# 4376                  1.0                           0.0     1.0  Orthodox
# 4438                  0.0                           0.0     0.0  Orthodox
# 4767                  0.0                           0.0     0.0  Orthodox
# 4908                  0.0                           0.0     0.0  Orthodox
#
#       R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 4171        177.80       182.88         155.0   32.0   29.0
# 4376        175.26       182.88         170.0   29.0   29.0
# 4438        175.26       182.88         170.0   28.0   29.0
# 4767        182.88       185.42         185.0   29.0   29.0
# 4908        172.72       185.42         170.0   26.0   29.0
#
# [5 rows x 145 columns]

# %% [markdown]
# # Visualizations

# %%
#correlation matrix and heat map 
corrMatrix = df.corr()
print (corrMatrix)
ax = sns.heatmap(corrMatrix)
ax
# Out:
#                        title_bout  no_of_rounds  B_current_lose_streak  \
# title_bout               1.000000      0.575194              -0.111945
# no_of_rounds             0.575194      1.000000              -0.042199
# B_current_lose_streak   -0.111945     -0.042199               1.000000
# B_current_win_streak     0.293195      0.321017              -0.382333
# B_draw                        NaN           NaN                    NaN
# ...                           ...           ...                    ...
# R_Height_cms             0.007314     -0.011291               0.008862
# R_Reach_cms              0.032548      0.049942               0.003763
# R_Weight_lbs             0.048565     -0.028012               0.008283
# B_age                    0.029451      0.120414               0.172089
# R_age                    0.008925      0.110531               0.051852
#
#                        B_current_win_streak  B_draw  B_avg_BODY_att  \
# title_bout                         0.293195     NaN        0.003156
# no_of_rounds                       0.321017     NaN        0.105479
# B_current_lose_streak             -0.382333     NaN        0.010658
# B_current_win_streak               1.000000     NaN        0.081102
# B_draw                                  NaN     NaN             NaN
# ...                                     ...     ...             ...
# R_Height_cms                       0.015802     NaN       -0.208626
# R_Reach_cms                        0.045540     NaN       -0.190165
# R_Weight_lbs                       0.029036     NaN       -0.229085
# B_age                              0.043065     NaN        0.003648
# R_age                              0.116328     NaN        0.068328
#
#                        B_avg_BODY_landed  B_avg_CLINCH_att  \
# title_bout                      0.014356          0.007569
# no_of_rounds                    0.110994          0.066853
# B_current_lose_streak          -0.008927          0.003491
# B_current_win_streak            0.091727          0.067924
# B_draw                               NaN               NaN
# ...                                  ...               ...
# R_Height_cms                   -0.174261         -0.067684
# R_Reach_cms                    -0.152686         -0.062667
# R_Weight_lbs                   -0.187547         -0.071793
# B_age                           0.014684          0.044531
# R_age                           0.069218          0.044868
#
#                        B_avg_CLINCH_landed  B_avg_DISTANCE_att  ...  \
# title_bout                        0.012233           -0.008395  ...
# no_of_rounds                      0.071127            0.110398  ...
# B_current_lose_streak            -0.006602            0.037272  ...
# B_current_win_streak              0.074238            0.065437  ...
# B_draw                                 NaN                 NaN  ...
# ...                                    ...                 ...  ...
# R_Height_cms                     -0.062819           -0.217659  ...
# R_Reach_cms                      -0.054875           -0.201071  ...
# R_Weight_lbs                     -0.063458           -0.252819  ...
# B_age                             0.061657           -0.026817  ...
# R_age                             0.050163            0.070692  ...
#
#                        R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# title_bout                                0.111307         0.159666
# no_of_rounds                              0.282520         0.334648
# B_current_lose_streak                    -0.019504        -0.006185
# B_current_win_streak                      0.283803         0.270637
# B_draw                                         NaN              NaN
# ...                                            ...              ...
# R_Height_cms                             -0.115647         0.205551
# R_Reach_cms                              -0.073939         0.221666
# R_Weight_lbs                             -0.128871         0.235335
# B_age                                     0.130575         0.241675
# R_age                                     0.286416         0.368442
#
#                        R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  \
# title_bout                        0.063659                      0.051920
# no_of_rounds                      0.084733                      0.049052
# B_current_lose_streak            -0.000229                     -0.009743
# B_current_win_streak              0.170242                      0.052670
# B_draw                                 NaN                           NaN
# ...                                    ...                           ...
# R_Height_cms                      0.061280                      0.021925
# R_Reach_cms                       0.093037                      0.060885
# R_Weight_lbs                     -0.006951                      0.044461
# B_age                             0.084508                      0.066314
# R_age                             0.175748                      0.133624
#
#                          R_wins  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# title_bout             0.156071      0.007314     0.032548      0.048565
# no_of_rounds           0.336652     -0.011291     0.049942     -0.028012
# B_current_lose_streak -0.007911      0.008862     0.003763      0.008283
# B_current_win_streak   0.339402      0.015802     0.045540      0.029036
# B_draw                      NaN           NaN          NaN           NaN
# ...                         ...           ...          ...           ...
# R_Height_cms           0.059898      1.000000     0.867503      0.776694
# R_Reach_cms            0.101966      0.867503     1.000000      0.709188
# R_Weight_lbs           0.048849      0.776694     0.709188      1.000000
# B_age                  0.224311      0.164597     0.163602      0.211914
# R_age                  0.413044      0.073786     0.069279      0.182848
#
#                           B_age     R_age
# title_bout             0.029451  0.008925
# no_of_rounds           0.120414  0.110531
# B_current_lose_streak  0.172089  0.051852
# B_current_win_streak   0.043065  0.116328
# B_draw                      NaN       NaN
# ...                         ...       ...
# R_Height_cms           0.164597  0.073786
# R_Reach_cms            0.163602  0.069279
# R_Weight_lbs           0.211914  0.182848
# B_age                  1.000000  0.187911
# R_age                  0.187911  1.000000
#
# [136 rows x 136 columns]

# %%
df.columns.tolist()
# Out:
# ['R_fighter',
#  'B_fighter',
#  'Referee',
#  'date',
#  'location',
#  'title_bout',
#  'weight_class',
#  'no_of_rounds',
#  'B_current_lose_streak',
#  'B_current_win_streak',
#  'B_draw',
#  'B_avg_BODY_att',
#  'B_avg_BODY_landed',
#  'B_avg_CLINCH_att',
#  'B_avg_CLINCH_landed',
#  'B_avg_DISTANCE_att',
#  'B_avg_DISTANCE_landed',
#  'B_avg_GROUND_att',
#  'B_avg_GROUND_landed',
#  'B_avg_HEAD_att',
#  'B_avg_HEAD_landed',
#  'B_avg_KD',
#  'B_avg_LEG_att',
#  'B_avg_LEG_landed',
#  'B_avg_PASS',
#  'B_avg_REV',
#  'B_avg_SIG_STR_att',
#  'B_avg_SIG_STR_landed',
#  'B_avg_SIG_STR_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_TD_att',
#  'B_avg_TD_landed',
#  'B_avg_TD_pct',
#  'B_avg_TOTAL_STR_att',
#  'B_avg_TOTAL_STR_landed',
#  'B_longest_win_streak',
#  'B_losses',
#  'B_avg_opp_BODY_att',
#  'B_avg_opp_BODY_landed',
#  'B_avg_opp_CLINCH_att',
#  'B_avg_opp_CLINCH_landed',
#  'B_avg_opp_DISTANCE_att',
#  'B_avg_opp_DISTANCE_landed',
#  'B_avg_opp_GROUND_att',
#  'B_avg_opp_GROUND_landed',
#  'B_avg_opp_HEAD_att',
#  'B_avg_opp_HEAD_landed',
#  'B_avg_opp_KD',
#  'B_avg_opp_LEG_att',
#  'B_avg_opp_LEG_landed',
#  'B_avg_opp_PASS',
#  'B_avg_opp_REV',
#  'B_avg_opp_SIG_STR_att',
#  'B_avg_opp_SIG_STR_landed',
#  'B_avg_opp_SIG_STR_pct',
#  'B_avg_opp_SUB_ATT',
#  'B_avg_opp_TD_att',
#  'B_avg_opp_TD_landed',
#  'B_avg_opp_TD_pct',
#  'B_avg_opp_TOTAL_STR_att',
#  'B_avg_opp_TOTAL_STR_landed',
#  'B_total_rounds_fought',
#  'B_total_time_fought(seconds)',
#  'B_total_title_bouts',
#  'B_win_by_Decision_Majority',
#  'B_win_by_Decision_Split',
#  'B_win_by_Decision_Unanimous',
#  'B_win_by_KO/TKO',
#  'B_win_by_Submission',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_wins',
#  'B_Stance',
#  'B_Height_cms',
#  'B_Reach_cms',
#  'B_Weight_lbs',
#  'R_current_lose_streak',
#  'R_current_win_streak',
#  'R_draw',
#  'R_avg_BODY_att',
#  'R_avg_BODY_landed',
#  'R_avg_CLINCH_att',
#  'R_avg_CLINCH_landed',
#  'R_avg_DISTANCE_att',
#  'R_avg_DISTANCE_landed',
#  'R_avg_GROUND_att',
#  'R_avg_GROUND_landed',
#  'R_avg_HEAD_att',
#  'R_avg_HEAD_landed',
#  'R_avg_KD',
#  'R_avg_LEG_att',
#  'R_avg_LEG_landed',
#  'R_avg_PASS',
#  'R_avg_REV',
#  'R_avg_SIG_STR_att',
#  'R_avg_SIG_STR_landed',
#  'R_avg_SIG_STR_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_TD_att',
#  'R_avg_TD_landed',
#  'R_avg_TD_pct',
#  'R_avg_TOTAL_STR_att',
#  'R_avg_TOTAL_STR_landed',
#  'R_longest_win_streak',
#  'R_losses',
#  'R_avg_opp_BODY_att',
#  'R_avg_opp_BODY_landed',
#  'R_avg_opp_CLINCH_att',
#  'R_avg_opp_CLINCH_landed',
#  'R_avg_opp_DISTANCE_att',
#  'R_avg_opp_DISTANCE_landed',
#  'R_avg_opp_GROUND_att',
#  'R_avg_opp_GROUND_landed',
#  'R_avg_opp_HEAD_att',
#  'R_avg_opp_HEAD_landed',
#  'R_avg_opp_KD',
#  'R_avg_opp_LEG_att',
#  'R_avg_opp_LEG_landed',
#  'R_avg_opp_PASS',
#  'R_avg_opp_REV',
#  'R_avg_opp_SIG_STR_att',
#  'R_avg_opp_SIG_STR_landed',
#  'R_avg_opp_SIG_STR_pct',
#  'R_avg_opp_SUB_ATT',
#  'R_avg_opp_TD_att',
#  'R_avg_opp_TD_landed',
#  'R_avg_opp_TD_pct',
#  'R_avg_opp_TOTAL_STR_att',
#  'R_avg_opp_TOTAL_STR_landed',
#  'R_total_rounds_fought',
#  'R_total_time_fought(seconds)',
#  'R_total_title_bouts',
#  'R_win_by_Decision_Majority',
#  'R_win_by_Decision_Split',
#  'R_win_by_Decision_Unanimous',
#  'R_win_by_KO/TKO',
#  'R_win_by_Submission',
#  'R_win_by_TKO_Doctor_Stoppage',
#  'R_wins',
#  'R_Stance',
#  'R_Height_cms',
#  'R_Reach_cms',
#  'R_Weight_lbs',
#  'B_age',
#  'R_age']

# %%
#training data 
df = df.drop(['B_fighter', 'R_fighter', 'Referee', 'date', 'location', 'weight_class'], axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(df, df, test_size=0.1, random_state=43)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-4766c4a12b05> in <module>
#       1 #training data
#       2 df = df.drop(['B_fighter', 'R_fighter', 'Referee', 'date', 'location', 'weight_class'], axis=1, inplace=True)
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(df, df, test_size=0.1, random_state=43)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2118     arrays = indexable(*arrays)
#    2119
# -> 2120     n_samples = _num_samples(arrays[0])
#    2121     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
#    2122                                               default_test_size=0.25)
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     145             x = np.asarray(x)
#     146         else:
# --> 147             raise TypeError(message)
#     148
#     149     if hasattr(x, 'shape') and x.shape is not None:
#
# TypeError: Expected sequence or array-like, got <class 'NoneType'>

# %%
#Confusion Matrix

# %%
neighbors = KNeighborsClassifier(n_neighbors = 3)

neighbors.fit (X_train, y_train)
predictions = neigh.predict(X_test)
print(accuracy_score(predidctions, y_test))
print(classification_report(predictions, y_test))
print(confusion_matrix(predictions, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-b251da3ed315> in <module>
#       1 neighbors = KNeighborsClassifier(n_neighbors = 3)
#       2
# ----> 3 neighbors.fit (X_train, y_train)
#       4 predictions = neigh.predict(X_test)
#       5 print(accuracy_score(predidctions, y_test))
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1128         """
#    1129         if not isinstance(X, (KDTree, BallTree)):
# -> 1130             X, y = check_X_y(X, y, "csr", multi_output=True)
#    1131
#    1132         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     745         raise ValueError("y cannot be None")
#     746
# --> 747     X = check_array(X, accept_sparse=accept_sparse,
#     748                     accept_large_sparse=accept_large_sparse,
#     749                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     569         # make sure we actually converted to numeric:
#     570         if dtype_numeric and array.dtype.kind == "O":
# --> 571             array = array.astype(np.float64)
#     572         if not allow_nd and array.ndim >= 3:
#     573             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'Hernani Perpetuo'
