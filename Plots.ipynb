# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
os.chdir("./dataFrames")
finalView = pd.read_csv('finalView.csv',  index_col=0)

# %% [markdown]
# # Lineplots

# %%
#For the Blue Corner

# %%
df2 = pd.read_csv("finalView.csv")
sns.jointplot(x="B_avg_TD_pct", y="B_wins", data=df2);

# %%
#A line plot for B_age and B_wins
sns.lineplot(x="B_age", y="B_wins", data=df2)

# %%
sns.lineplot(x="B_wins", y = "B_total_rounds_fought", data=df2)

# %%
#A line plot between B height and B Wins
sns.lineplot(x="B_Height_cms", y="B_wins", data=df2)

# %%
#A line plot between B Reach and B Wins
sns.lineplot(x="B_Reach_cms", y="B_wins", data=df2)

# %%
#A line plot between B Height and B Losses
sns.lineplot(x="B_Height_cms", y="B_losses", data=df2)

# %%
#A line plot betwen B and and B losses
sns.lineplot(x="B_age", y="B_losses", data=df2)

# %%
sns.lineplot(x="B_avg_LEG_att", y="B_wins", data=df2)

# %%
#A line plot between B average significant strikes and their wins
sns.lineplot(x="B_avg_SIG_STR_att", y="B_wins", data=df2)

# %%
#A line plot between B average significant strikes percentages and their wins" 
sns.lineplot(x="B_avg_SIG_STR_pct", y="B_wins", data=df2)

# %%
#A line plot for B average takedown percentages and their wins. 
sns.lineplot(x="B_avg_TD_pct", y="B_wins", data=df2)

# %%
sns.lineplot(x="B_longest_win_streak", y="B_age", data=df2)

# %%
sns.lineplot(x="B_total_time_fought(seconds)", y="B_wins", data=df2)

# %%
sns.lineplot(x="B_age", y="B_win_by_Decision_Unanimous", data=df2)

# %%
sns.lineplot(x="B_age", y="B_win_by_TKO_Doctor_Stoppage", data=df2)

# %%
df2 = pd.read_csv("finalView.csv")
sns.jointplot(x="B_Height_cms", y="B_wins", data=df2);

# %%
#For the Red Corner.

# %%
df2 = pd.read_csv("finalView.csv")
sns.jointplot(x="R_avg_SIG_STR_pct", y="R_wins", data=df2);

# %%
#A line plot for R_age and R_wins
sns.lineplot(x="R_age", y="R_wins", data=df2)

# %%
#A line plot between R height and R Wins
sns.lineplot(x="R_Height_cms", y="R_wins", data=df2)

# %%
#A line plot between R Reach and R Wins
sns.lineplot(x="R_Reach_cms", y="R_wins", data=df2)

# %%
#A line plot between R Height and R Losses
sns.lineplot(x="R_Height_cms", y="R_losses", data=df2)

# %%
#A line plot betwen R and and R losses
sns.lineplot(x="R_age", y="R_losses", data=df2)

# %%
sns.lineplot(x="R_avg_LEG_att", y="R_wins", data=df2)

# %%
#A line plot between R average significant strikes and their wins
sns.lineplot(x="R_avg_SIG_STR_att", y="R_wins", data=df2)

# %%
#A line plot between R average significant strikes percentages and their wins" 
sns.lineplot(x="R_avg_SIG_STR_pct", y="R_wins", data=df2)

# %%
#A line plot for B average takedown percentages and their wins. 
sns.lineplot(x="R_avg_TD_pct", y="R_wins", data=df2)

# %%
sns.lineplot(x="R_longest_win_streak", y="R_age", data=df2)

# %%
sns.lineplot(x="R_total_time_fought(seconds)", y="R_wins", data=df2)

# %%
sns.lineplot(x="R_age", y="R_win_by_Decision_Unanimous", data=df2)

# %%
sns.lineplot(x="R_age", y="R_win_by_TKO_Doctor_Stoppage", data=df2)

# %%
sns.lineplot(x="R_wins", y="R_total_rounds_fought", data = df2)

# %%
df2 = pd.read_csv("finalView.csv")
sns.jointplot(x="R_Height_cms", y="R_wins", data=df2);

# %% [markdown]
# # Categorical Plots

# %%
#Based on gender.

# %%
#A categorical plot separating out gender, their average body attacks and average clinch attacks
import seaborn as sns
df2 = finalView
sns.catplot(x="B_avg_TD_pct", y="B_wins", hue="Gender", data=df2)
#sns.catplot(x="B_avg_BODY_att", y="B_avg_CLINCH_att", hue="Gender", col="Winner",  data=df2)

# %%
sns.catplot(x="B_Height_cms", y="B_wins", hue="Gender", col="Winner",  data=df2)

# %%
sns.catplot(x="B_Weight_lbs", y="B_wins", hue="Gender", col="Winner",  data=df2)

# %%
#Based on the winner being the red corner or the blue corner.

# %%
df2.head()
df2.loc[df2['Winner'] =="Red", 'Loser'] = "Blue"
df2.loc[df2['Winner'] =="Blue", 'Loser'] = "Red"
df2.tail()
# Out:
#       Unnamed: 0        R_fighter        B_fighter            Referee  \
# 1657        2073      Miesha Tate      Sara McMann       Marc Goddard
# 1658        2266  Jessica Andrade  Larissa Pacheco  Fernando Yamasaki
# 1659        2352  Claudia Gadelha   Tina Lahdemaki      Liam Kerrigan
# 1660        2798     Amanda Nunes      Sheila Gaff          Herb Dean
# 1661        2830     Alexis Davis      Rosi Sexton          Herb Dean
#
#             date                            location Winner  title_bout  \
# 1657  2015-01-31              Las Vegas, Nevada, USA    Red       False
# 1658  2014-09-13  Brasilia, Distrito Federal, Brazil    Red       False
# 1659  2014-07-16      Atlantic City, New Jersey, USA    Red       False
# 1660  2013-08-03              Rio de Janeiro, Brazil    Red       False
# 1661  2013-06-15          Winnipeg, Manitoba, Canada    Red       False
#
#               weight_class  no_of_rounds  ...  R_win_by_TKO_Doctor_Stoppage  \
# ...

# %%
df2.tail(1468)
# Out:
#       Unnamed: 0        R_fighter         B_fighter            Referee  \
# 194          269   Keita Nakamura     Salim Touahri        Jim Perdios
# 195          270     Elias Garcia   Kai Kara-France     Greg Kleynjans
# 196          272     Alex Gorgees   Damir Ismagulov       Neil Swailes
# 197          276     Pedro Munhoz     Bryan Caraway      Chris Tognoni
# 198          277   Darren Stewart  Edmen Shahbazyan         Mark Smith
# ...          ...              ...               ...                ...
# 1657        2073      Miesha Tate       Sara McMann       Marc Goddard
# 1658        2266  Jessica Andrade   Larissa Pacheco  Fernando Yamasaki
# 1659        2352  Claudia Gadelha    Tina Lahdemaki      Liam Kerrigan
# 1660        2798     Amanda Nunes       Sheila Gaff          Herb Dean
# 1661        2830     Alexis Davis       Rosi Sexton          Herb Dean
#
#             date                              location Winner  title_bout  \
# ...

# %%
sns.catplot(x="B_avg_BODY_landed", y="B_avg_CLINCH_landed", hue="B_fighter", data=df2.tail(10))

# %%
import seaborn as sns
sns.catplot(x="B_avg_BODY_landed", y="B_avg_CLINCH_landed", hue="Gender", col="Winner", data=df2.tail(1468))
sns.catplot(x="B_avg_HEAD_landed", y="B_avg_GROUND_landed", hue="Gender", col="Winner", data=df2.tail(1468))

# %%
sns.catplot(x="B_avg_KD", y="B_avg_LEG_landed", hue="Gender", col="Winner", data=df2.tail(1468))
sns.catplot(x="B_avg_PASS", y="B_avg_REV", hue="Gender", col="Winner", data=df2.tail(1468))

# %%
sns.catplot(x="B_avg_opp_SIG_STR_landed", y="B_avg_opp_REV", hue="Gender", col="Winner", data=df2.tail(1468))
sns.catplot(x="B_avg_opp_SIG_STR_pct", y="B_avg_opp_TD_landed", hue="Gender", col="Winner", data=df2.tail(1468))
